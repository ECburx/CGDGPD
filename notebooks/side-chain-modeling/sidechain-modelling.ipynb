# %% [markdown]
# # Homology Modelling of Side Chains

# %%
from pathlib import Path

# change accordingly
GENERATED_CLS = GENERATED_CLS if "GENERATED_CLS" in locals() else "GFP"
GENERATED_SID = GENERATED_SID if "GENERATED_SID" in locals() else "FM_10"
assert GENERATED_CLS is not None
assert GENERATED_SID is not None

MIN_HOMOLOGY = MIN_HOMOLOGY if "MIN_HOMOLOGY" in locals() else 0.35
MIN_TM_SCORE = MIN_TM_SCORE if "MIN_TM_SCORE" in locals() else 0.8
MAX_TEMPLATES = MAX_TEMPLATES if "MAX_TEMPLATES" in locals() else 5
print(
    f"Homology Modelling: {GENERATED_CLS}/{GENERATED_SID}. Min Homology = {MIN_HOMOLOGY}. Maximum Number of Templates to Use = {MAX_TEMPLATES}.")

GENERATED_PDB = Path(f"../../data/{GENERATED_CLS}/generated/BQ/{GENERATED_SID}.pdb")
GENERATED_SEQ = Path(f"../../data/{GENERATED_CLS}/generated/Q/{GENERATED_SID}.fasta")
# Out:
# Homology Modelling: GFP/FM_10. Min Homology = 0.35. Maximum Number of Templates to Use = 5.

# %% [markdown]
# Identy and select template structures for subsequent homology modelling of side chains.
#
# - Use FoldSeek for sequence + structure alignment.
# - The homology should be at least 70%.
#
# You may wish to increase the limit on the data rate that the notebook server can send to clients and the window size used to compute the average data rate for the limit, by adding the following tags:
#
# ```
# notebook --ServerApp.iopub_data_rate_limit 10000000.0 --ServerApp.rate_limit_window=25.0
# ```

# %%
from time import sleep

from requests import get, post

TICKET_URL = "https://search.foldseek.com/api/ticket"
RESULT_URL = "https://search.foldseek.com/api/result"

# submit a new job
# curl -X POST -F q=@{GEN_PDB} -F 'mode=tmalign' -F 'database[]=pdb100' https://search.foldseek.com/api/ticket
with open(GENERATED_PDB, 'rb') as f:
    ticket = post(
        TICKET_URL,
        files={'q': f},
        data={
            "mode": "tmalign",
            "database[]": "pdb100"
        }).json()
    print("Job submitted:", ticket)

repeat = True
while repeat:
    status = get(f"{TICKET_URL}/{ticket['id']}").json()
    print("Running status:", ticket)
    if status["status"] == "ERROR":
        break
    sleep(1)
    repeat = status["status"] != "COMPLETE"

result = get(f"{RESULT_URL}/{ticket['id']}/0").json()
# import json
# with open("result.json", "w") as json_file:
#     json.dump(result, json_file, indent=4)
result = result["results"][0]["alignments"][0]

visited = set()
templates = [
                {"PDB": pdb,
                 "seq": alignment["tSeq"],
                 "tm-score": alignment["eval"],
                 "prob": alignment["prob"],
                 "seq-per-identity": alignment["seqId"],
                 }
                for alignment in result
                if alignment["seqId"] > MIN_HOMOLOGY
                if alignment["eval"] > MIN_HOMOLOGY
                if (pdb := alignment["target"].split("-")[0].upper()) not in visited and not visited.add(pdb)
                if pdb not in ["6WJM", "6WGP", "2QU1"]
            ][:min(MAX_TEMPLATES, len(result))]
# Out:
# Job submitted: {'id': 'SC7dw7VFfKF09_WuI__16gQYtB_NEa6qdo1z_A', 'status': 'COMPLETE'}
# Running status: {'id': 'SC7dw7VFfKF09_WuI__16gQYtB_NEa6qdo1z_A', 'status': 'COMPLETE'}

# %% [markdown]
# Prepare (1) working directory, (2) FASTAs for alignment, (3) PDBs for homology modelling.

# %%
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio import PDB, SeqIO
import shutil

wd = Path(f"wd/{GENERATED_CLS}/{GENERATED_SID}")
wd.mkdir(parents=True, exist_ok=True)

pdb_dir = wd / "pdb"
pdb_dir.mkdir(parents=True, exist_ok=True)

fasta = wd / "seqs.fasta"
fasta_seqs = [SeqIO.read(GENERATED_SEQ, "fasta")]
parser = PDB.PDBParser()

shutil.copy(
    src=GENERATED_PDB,
    dst=pdb_dir / GENERATED_PDB.name
)

for temp in templates:
    temp_id = temp["PDB"]
    for temp_pdb in Path(f"../../data/{GENERATED_CLS}/processed").glob(f"{temp_id}*.pdb"):
        print(f"Template {temp_pdb.stem}")
        shutil.copy(
            src=temp_pdb,
            dst=pdb_dir / temp_pdb.name
        )
        structure = parser.get_structure('structure', temp_pdb)
        sequence = ''
        for model in structure:
            for chain in model:
                for residue in chain:
                    if PDB.is_aa(residue, standard=True):
                        sequence += PDB.Polypeptide.index_to_one(PDB.Polypeptide.three_to_index(residue.resname))
        fasta_seqs.append(SeqRecord(Seq(sequence), id=temp_pdb.stem, description=""))

with open(fasta, "w") as f:
    SeqIO.write(fasta_seqs, f, format="fasta")
# Out:
# Template 1Q4D_A
# Template 5NI3_D
# Template 5NI3_B
# Template 5NI3_C
# Template 5NI3_A
# Template 1EMA_A
# Template 2DUI_A
# Template 1YFP_A
# Template 1YFP_B

# %% [markdown]
# Align sequences using Clustal.

# %%
# !clustalw -infile={fasta} -output=pir

# !echo clustalo -i {fasta} -o {fasta.parent}/{fasta.stem}.aln.fasta --outfmt=fa
# !clustalo -i {fasta} -o {fasta.parent}/{fasta.stem}.aln.fasta --outfmt=fa

# !echo seqret -sequence {fasta.parent}/{fasta.stem}.aln.fasta -outseq {fasta.parent}/{fasta.stem}.pir -osformat2 pir
# !seqret -sequence {fasta.parent}/{fasta.stem}.aln.fasta -outseq {fasta.parent}/{fasta.stem}.pir -osformat2 pir
# Out:
# clustalo -i wd/GFP/FM_10/seqs.fasta -o wd/GFP/FM_10/seqs.aln.fasta --outfmt=fa
# seqret -sequence wd/GFP/FM_10/seqs.aln.fasta -outseq wd/GFP/FM_10/seqs.pir -osformat2 pir
# Read and write (return) sequences

# %% [markdown]
# Fill the missing details in the PIR alignment.

# %%
PIR_RAW = fasta.parent / f"{fasta.stem}.pir"
PIR_REF = PIR_RAW.parent / f"{PIR_RAW.stem}.ref.pir"

entries = []

# l1: >P1;8DOD
# l2: StructureX:8DOD.pdb:26:A:290:::::
# lx: <SEQUENCE>
with open(PIR_RAW, "r") as i, open(PIR_REF, "w") as o:
    entry_id = None
    l2 = False
    for l in i:
        # l1
        if l.startswith(">P1;"):
            entry_id = l[4:].split(" ")[0].strip()
            l2 = True
            o.write(l)
        # l2
        elif l2:
            l2 = False
            chain_id = None
            try:
                chain_id = next(Path(f"../../data/{GENERATED_CLS}/processed").glob(f"{entry_id}*.pdb")).stem.split("_")[-1]
            except StopIteration:
                chain_id = "A"
            start, end = float('inf'), float('-inf')
            for model in parser.get_structure('structure', pdb_dir / f"{entry_id}.pdb"):
                for chain in model:
                    if chain.id != chain_id:
                        continue
                    for residue in chain:
                        if PDB.is_aa(residue, standard=True):
                            start = min(residue.id[1], start)
                            end = max(residue.id[1], start)
            o.write(f"StructureX:{entry_id}.pdb:{start}:{chain_id}:{end}:::::\n")
            entries.append(entry_id)
        # lx
        else:
            o.write(l)

entries.remove(GENERATED_SID)

# %% [markdown]
# Homology modelling of side chains.
# Main chains are fixed.
# Load model from the existing backbone structure.
#
# Model 10 times; select the best one.
#
# You may need to manually edit the data to avoid potential errors.

# %%
# %cd {wd}

from modeller import *
from modeller.automodel import *
from modeller.scripts import *

# log.verbose()
env = Environ()


class SidechainModel(AutoModel):
    def select_atoms(self):
        return Selection(self).only_sidechain()


env.io.atom_files_directory = "./pdb"

a = SidechainModel(
    env,
    alnfile=PIR_REF.name,
    knowns=entries,
    sequence=GENERATED_SID,
    inifile=str(f"./pdb/{GENERATED_PDB.name}")
)
a.starting_model = 1
a.ending_model = 10
a.assess_methods = [assess.DOPE]
a.make()
# Out:
# /home/tz365/miniconda3/envs/proteval/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /home/tz365/WS/PROTEVAL/notebooks/side-chain-modelng/wd/GFP/FM_10
#
#                          MODELLER 10.6, 2024/10/17, r12888
#
#      PROTEIN STRUCTURE MODELLING BY SATISFACTION OF SPATIAL RESTRAINTS
#
#
#                      Copyright(c) 1989-2024 Andrej Sali
#                             All Rights Reserved
#
#                              Written by A. Sali
#                                with help from
#               B. Webb, M.S. Madhusudhan, M-Y. Shen, G.Q. Dong,
#           M.A. Marti-Renom, N. Eswar, F. Alber, M. Topf, B. Oliva,
#              A. Fiser, R. Sanchez, B. Yerkovich, A. Badretdinov,
#                      F. Melo, J.P. Overington, E. Feyfant
#                  University of California, San Francisco, USA
#                     Rockefeller University, New York, USA
#                       Harvard University, Cambridge, USA
#                    Imperial Cancer Research Fund, London, UK
#               Birkbeck College, University of London, London, UK
#
#
# Kind, OS, HostName, Kernel, Processor: 4, Linux 23OCT-4090-70K 5.15.167.4-microsoft-standard-WSL2 x86_64
# Date and time of compilation         : 2024/10/17 20:34:40
# MODELLER executable type             : x86_64-intel8
# Job starting time (YY/MM/DD HH:MM:SS): 2025/03/25 16:24:03
#
# IOData_____W> Setting io.atom_files_directory to a colon-delimited string is
#               deprecated, as it is not robust on Windows systems. Set it to
#               a list of directories instead. For example:
#               env.io.atom_files_directory = ['./pdb']
# readlinef__W> File: ./pdb/1Q4D_A.pdb, Line: 1792
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: ./pdb/5NI3_D.pdb, Line: 1795
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: ./pdb/5NI3_B.pdb, Line: 1819
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: ./pdb/5NI3_C.pdb, Line: 1814
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: ./pdb/5NI3_A.pdb, Line: 1790
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: ./pdb/2DUI_A.pdb, Line: 1777
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: ./pdb/1YFP_A.pdb, Line: 1678
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: ./pdb/1YFP_B.pdb, Line: 1678
#               Modeller will only read the first 80 characters of this line.
#
#
# check_ali___> Checking pairwise structural superpositions.
#
# Equivalent CA pairs with distance difference larger than  6.0 angstroms:
#
# ALN_POS TMPL1 TMPL2  RID1  RID2  NAM1  NAM2     DIST
# ----------------------------------------------------
#     232     3     4  233   233      M     M    8.311
# END OF TABLE
#
# check_ali___> Checking the sequence-structure alignment.
#
# Implied intrachain target CA(i)-CA(i+1) distances longer than  8.0 angstroms:
#
# ALN_POS  TMPL  RID1  RID2  NAM1  NAM2     DIST
# ----------------------------------------------
# END OF TABLE
# read_to_681_> topology.submodel read from topology file:        3
# readlinef__W> File: ./pdb/FM_10.pdb, Line: 1141
#               Modeller will only read the first 80 characters of this line.
#
# mdtrsr__446W> A potential that relies on one protein is used, yet you have at
#               least one known structure available. MDT, not library, potential is used.
# 0 atoms in HETATM/BLK residues constrained
# to protein atoms within 2.30 angstroms
# and protein CA atoms within 10.00 angstroms
# 0 atoms in residues without defined topology
# constrained to be rigid bodies
# condens_443_> Restraints marked for deletion were removed.
#               Total number of restraints before, now:    21284    19636
# 800 (of 1713 total) atoms selected for optimization
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  LEU:OXT  LEU
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713     800
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    19636    7115
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   231820
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -13591.4756
#
#
#
#
# << end of ENERGY.
# DOPE score               : -13591.475586
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713     800
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    19636    7115
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     2296
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        3740.7593
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :     841       0      1   0.007   0.007      10.739       1.000
#  2 Bond angle potential               :    1240       1      6   2.542   2.542      152.56       1.000
#  3 Stereochemical cosine torsion poten:    1081       0     38  52.228  52.228      466.99       1.000
#  4 Stereochemical improper torsion pot:     449       1      4   2.345   2.345      42.443       1.000
#  5 Soft-sphere overlap restraints     :    2296       0      1   0.007   0.007      13.482       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :       0       0      0   0.000   0.000      0.0000       1.000
# 10 Distance restraints 2 (N-O)        :       0       0      0   0.000   0.000      0.0000       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 14 Sidechain Chi_1 dihedral restraints:     183       0      5  79.880  79.880      80.690       1.000
# 15 Sidechain Chi_2 dihedral restraints:     134       0      4  75.593  75.593      53.490       1.000
# 16 Sidechain Chi_3 dihedral restraints:      65       0      0  57.869  57.869      31.287       1.000
# 17 Sidechain Chi_4 dihedral restraints:      28       0      0 103.042 103.042      20.785       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :    2433       0      0   0.629   0.629      1971.9       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :     661      15     64   1.989   1.989      896.36       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: FM_10.V99990001
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   14571.5869
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
# -------------------------------------------------------------------------------------------------
#
# Feature  4                           : Stereochemical improper torsion potentia
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1   5438  68F  68F CA  N     495  494   56.36   35.27   21.10    5.03   35.27   21.10    5.03
#
# -------------------------------------------------------------------------------------------------
#
# Feature 26                           : Distance restraints 4 (SDCH-SDCH)
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1  19002   7L  83C CB  SG     45  604   12.33    4.80    7.53    4.96    4.80    7.53    4.96
#     2  19004  11V  68F CB  CD1    76  498   11.31    5.11    6.20    5.15    5.11    6.20    5.15
#     3  19005  11V  68F CB  CE1    76  500   10.38    3.80    6.58    5.85    3.80    6.58    5.85
#     4  19006  11V  68F CB  CZ     76  502   10.56    3.90    6.66    5.89    3.90    6.66    5.89
#     5  19008  11V  68F CG1 CE1    77  500   10.24    4.37    5.87    5.05    4.37    5.87    5.05
#     6  19009  11V  68F CG1 CZ     77  502   10.30    3.97    6.33    5.55    3.97    6.33    5.55
#     7  19017  11V  68F CG2 CE1    78  500   10.17    4.23    5.94    5.10    4.23    5.94    5.10
#     8  19018  11V  68F CG2 CZ     78  502   10.54    4.67    5.87    4.99    4.67    5.87    4.99
#     9  19033  13V  68F CB  CE2    90  501   10.96    5.08    5.88    4.87    5.08    5.88    4.87
#    10  19182  42L  68F CG  CB    304  496   10.83    4.17    6.67    5.38    4.17    6.67    5.38
#    11  19194  42L  68F CD2 CB    306  496    9.98    3.80    6.18    5.08    3.80    6.18    5.08
#    12  19254  66Y  82C CB  CB    478  597   13.33    5.00    8.33    6.57    5.00    8.33    6.57
#    13  19255  66Y  82C CB  SG    478  598   12.21    4.17    8.04    6.73    4.17    8.04    6.73
#    14  19259  67S  83C CB  SG    490  604   14.33    4.37    9.97    8.50    4.37    9.97    8.50
#    15  19319  82C 159I SG  CD1   598 1170   11.27    5.07    6.21    4.55    5.07    6.21    4.55
#
#
# report______> Distribution of short non-bonded contacts:
#
#   serious non-bonded atom clash:    88  235   2.241
#   serious non-bonded atom clash:   246  300   2.028
#   serious non-bonded atom clash:   263  286   1.945
#   serious non-bonded atom clash:   444  454   2.237
#   serious non-bonded atom clash:   444  456   2.060
#   serious non-bonded atom clash:   616  638   2.107
#   serious non-bonded atom clash:  1037 1041   1.968
#   serious non-bonded atom clash:  1228 1235   2.208
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     4    1    3    2    4   12   31   91  116  168  182  181  193  212  287
#
#
# << end of ENERGY.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  LEU:OXT  LEU
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713     800
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    19636    7115
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   228956
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -13257.1289
#
#
#
#
# << end of ENERGY.
# DOPE score               : -13257.128906
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713     800
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    19636    7115
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     2210
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        3691.7717
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :     841       0      1   0.009   0.009      16.570       1.000
#  2 Bond angle potential               :    1240       1      7   2.599   2.599      157.31       1.000
#  3 Stereochemical cosine torsion poten:    1081       0     39  52.087  52.087      463.84       1.000
#  4 Stereochemical improper torsion pot:     449       1      2   2.212   2.212      38.057       1.000
#  5 Soft-sphere overlap restraints     :    2210       0      2   0.009   0.009      22.986       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :       0       0      0   0.000   0.000      0.0000       1.000
# 10 Distance restraints 2 (N-O)        :       0       0      0   0.000   0.000      0.0000       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 14 Sidechain Chi_1 dihedral restraints:     183       0      8  77.825  77.825      81.332       1.000
# 15 Sidechain Chi_2 dihedral restraints:     134       0      0  69.852  69.852      33.222       1.000
# 16 Sidechain Chi_3 dihedral restraints:      65       0      0  61.668  61.668      37.978       1.000
# 17 Sidechain Chi_4 dihedral restraints:      28       0      0  81.551  81.551      17.287       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :    2433       0      3   0.564   0.564      1941.1       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :     661      15     72   1.909   1.909      882.10       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: FM_10.V99990002
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   13412.6562
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
# -------------------------------------------------------------------------------------------------
#
# Feature  4                           : Stereochemical improper torsion potentia
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1   5438  68F  68F CA  N     495  494   57.49   35.27   22.23    5.30   35.27   22.23    5.30
#
# -------------------------------------------------------------------------------------------------
#
# Feature 26                           : Distance restraints 4 (SDCH-SDCH)
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1  19002   7L  83C CB  SG     45  604   11.99    4.80    7.19    4.73    4.80    7.19    4.73
#     2  19004  11V  68F CB  CD1    76  498   11.27    5.11    6.16    5.12    5.11    6.16    5.12
#     3  19005  11V  68F CB  CE1    76  500   10.31    3.80    6.51    5.79    3.80    6.51    5.79
#     4  19006  11V  68F CB  CZ     76  502   10.41    3.90    6.51    5.75    3.90    6.51    5.75
#     5  19008  11V  68F CG1 CE1    77  500   10.17    4.37    5.80    4.99    4.37    5.80    4.99
#     6  19009  11V  68F CG1 CZ     77  502   10.14    3.97    6.17    5.41    3.97    6.17    5.41
#     7  19017  11V  68F CG2 CE1    78  500   10.08    4.23    5.84    5.02    4.23    5.84    5.02
#     8  19018  11V  68F CG2 CZ     78  502   10.37    4.67    5.71    4.84    4.67    5.71    4.84
#     9  19033  13V  68F CB  CE2    90  501   10.81    5.08    5.74    4.75    5.08    5.74    4.75
#    10  19182  42L  68F CG  CB    304  496   10.81    4.17    6.64    5.35    4.17    6.64    5.35
#    11  19194  42L  68F CD2 CB    306  496    9.96    3.80    6.16    5.06    3.80    6.16    5.06
#    12  19254  66Y  82C CB  CB    478  597   13.62    5.00    8.62    6.79    5.00    8.62    6.79
#    13  19255  66Y  82C CB  SG    478  598   12.24    4.17    8.08    6.76    4.17    8.08    6.76
#    14  19259  67S  83C CB  SG    490  604   12.63    4.37    8.27    7.05    4.37    8.27    7.05
#    15  19315  82C  90Y CB  OH    597  651   10.28    4.20    6.08    4.90    4.20    6.08    4.90
#
#
# report______> Distribution of short non-bonded contacts:
#
#   serious non-bonded atom clash:    88  235   2.241
#   serious non-bonded atom clash:   246  300   2.028
#   serious non-bonded atom clash:   263  286   1.945
#   serious non-bonded atom clash:   444  454   2.237
#   serious non-bonded atom clash:   444  456   2.060
#   serious non-bonded atom clash:   616  638   2.107
#   serious non-bonded atom clash:  1037 1041   1.968
#   serious non-bonded atom clash:  1228 1235   2.208
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     4    1    3    2    4   16   32   93  109  167  173  174  199  219  271
#
#
# << end of ENERGY.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  LEU:OXT  LEU
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713     800
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    19636    7115
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   231041
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -12955.1777
#
#
#
#
# << end of ENERGY.
# DOPE score               : -12955.177734
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713     800
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    19636    7115
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     2307
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        3841.2319
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :     841       0      1   0.009   0.009      16.454       1.000
#  2 Bond angle potential               :    1240       1      5   2.845   2.845      188.02       1.000
#  3 Stereochemical cosine torsion poten:    1081       0     40  52.187  52.187      469.44       1.000
#  4 Stereochemical improper torsion pot:     449       2      6   2.873   2.873      62.872       1.000
#  5 Soft-sphere overlap restraints     :    2307       0      0   0.006   0.006      11.098       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :       0       0      0   0.000   0.000      0.0000       1.000
# 10 Distance restraints 2 (N-O)        :       0       0      0   0.000   0.000      0.0000       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 14 Sidechain Chi_1 dihedral restraints:     183       0      9  81.408  81.408      122.16       1.000
# 15 Sidechain Chi_2 dihedral restraints:     134       0      5  76.683  76.683      59.859       1.000
# 16 Sidechain Chi_3 dihedral restraints:      65       0      0  58.943  58.943      28.979       1.000
# 17 Sidechain Chi_4 dihedral restraints:      28       0      0  71.162  71.162      17.674       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :    2433       0      2   0.630   0.630      1972.6       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :     661      14     72   1.957   1.957      892.12       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: FM_10.V99990003
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   14607.1299
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
# -------------------------------------------------------------------------------------------------
#
# Feature  4                           : Stereochemical improper torsion potentia
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1   5438  68F  68F CA  N     495  494   59.56   35.27   24.30    5.79   35.27   24.30    5.79
#
# -------------------------------------------------------------------------------------------------
#
# Feature 26                           : Distance restraints 4 (SDCH-SDCH)
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1  19004  11V  68F CB  CD1    76  498   11.13    5.11    6.02    5.00    5.11    6.02    5.00
#     2  19005  11V  68F CB  CE1    76  500   10.14    3.80    6.34    5.64    3.80    6.34    5.64
#     3  19006  11V  68F CB  CZ     76  502   10.28    3.90    6.38    5.64    3.90    6.38    5.64
#     4  19008  11V  68F CG1 CE1    77  500    9.97    4.37    5.61    4.82    4.37    5.61    4.82
#     5  19009  11V  68F CG1 CZ     77  502    9.98    3.97    6.01    5.27    3.97    6.01    5.27
#     6  19017  11V  68F CG2 CE1    78  500    9.97    4.23    5.73    4.93    4.23    5.73    4.93
#     7  19018  11V  68F CG2 CZ     78  502   10.31    4.67    5.64    4.79    4.67    5.64    4.79
#     8  19033  13V  68F CB  CE2    90  501   10.64    5.08    5.56    4.61    5.08    5.56    4.61
#     9  19182  42L  68F CG  CB    304  496   10.75    4.17    6.59    5.31    4.17    6.59    5.31
#    10  19194  42L  68F CD2 CB    306  496    9.92    3.80    6.12    5.02    3.80    6.12    5.02
#    11  19254  66Y  82C CB  CB    478  597   13.46    5.00    8.46    6.67    5.00    8.46    6.67
#    12  19255  66Y  82C CB  SG    478  598   14.02    4.17    9.85    8.24    4.17    9.85    8.24
#    13  19259  67S  83C CB  SG    490  604   12.37    4.37    8.00    6.82    4.37    8.00    6.82
#    14  19319  82C 159I SG  CD1   598 1170   11.67    5.07    6.60    4.83    5.07    6.60    4.83
#
#
# report______> Distribution of short non-bonded contacts:
#
#   serious non-bonded atom clash:    88  235   2.241
#   serious non-bonded atom clash:   246  300   2.028
#   serious non-bonded atom clash:   263  286   1.945
#   serious non-bonded atom clash:   444  454   2.237
#   serious non-bonded atom clash:   444  456   2.060
#   serious non-bonded atom clash:   616  638   2.107
#   serious non-bonded atom clash:  1037 1041   1.968
#   serious non-bonded atom clash:  1228 1235   2.208
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     4    1    3    2    4   14   30   92  117  152  186  198  210  228  281
#
#
# << end of ENERGY.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_484W> Dihedral still outside +-90:      -90.4302
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  LEU:OXT  LEU
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713     800
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    19636    7115
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   231021
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -13733.8203
#
#
#
#
# << end of ENERGY.
# DOPE score               : -13733.820312
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713     800
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    19636    7115
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     2216
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        3722.9419
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :     841       1      3   0.010   0.010      19.756       1.000
#  2 Bond angle potential               :    1240       2      3   2.646   2.646      166.98       1.000
#  3 Stereochemical cosine torsion poten:    1081       0     42  52.267  52.267      465.72       1.000
#  4 Stereochemical improper torsion pot:     449       1      2   2.113   2.113      34.075       1.000
#  5 Soft-sphere overlap restraints     :    2216       1      5   0.012   0.012      34.606       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :       0       0      0   0.000   0.000      0.0000       1.000
# 10 Distance restraints 2 (N-O)        :       0       0      0   0.000   0.000      0.0000       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 14 Sidechain Chi_1 dihedral restraints:     183       0      9  77.525  77.525      92.325       1.000
# 15 Sidechain Chi_2 dihedral restraints:     134       0      1  69.883  69.883      38.931       1.000
# 16 Sidechain Chi_3 dihedral restraints:      65       0      0  64.608  64.608      36.314       1.000
# 17 Sidechain Chi_4 dihedral restraints:      28       0      0  76.748  76.748      15.796       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :    2433       0      1   0.570   0.570      1949.7       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :     661      15     62   1.857   1.857      868.74       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: FM_10.V99990004
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   13424.7812
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
# ...
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: FM_10.V99990009
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   14217.6699
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
# -------------------------------------------------------------------------------------------------
#
# Feature 26                           : Distance restraints 4 (SDCH-SDCH)
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1
#
# Select the best model with the lowest score.

# %%
import pandas as pd
import os

lowest_dope = float('inf')
best_model = None

scores = pd.DataFrame([
    {"Model": str(model),
     "DOPE Score": complete_pdb(env, str(model)).assess_normalized_dope()
     } for model in Path("./").glob(f"{GENERATED_SID}.B*.pdb")
]).sort_values(by="DOPE Score", ascending=True)
print(scores)

os.rename(scores.iloc[0]['Model'], f"{GENERATED_SID}.best.pdb")
# Out:
# readlinef__W> File: FM_10.B99990008.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  LEU:OXT  LEU
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713    1713
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   326626
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -20044.4883
#
#
#
#
# << end of ENERGY.
# DOPE score               : -20044.488281
# >> Normalized DOPE z score: 0.105
# readlinef__W> File: FM_10.B99990003.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  LEU:OXT  LEU
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713    1713
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   327500
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -19680.0645
#
#
#
#
# << end of ENERGY.
# DOPE score               : -19680.064453
# >> Normalized DOPE z score: 0.218
# readlinef__W> File: FM_10.B99990010.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  LEU:OXT  LEU
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713    1713
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   326258
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -20399.3867
#
#
#
#
# << end of ENERGY.
# DOPE score               : -20399.386719
# >> Normalized DOPE z score: -0.005
# readlinef__W> File: FM_10.B99990006.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  LEU:OXT  LEU
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713    1713
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   328396
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -20655.7637
#
#
#
#
# << end of ENERGY.
# DOPE score               : -20655.763672
# >> Normalized DOPE z score: -0.085
# readlinef__W> File: FM_10.B99990005.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  LEU:OXT  LEU
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713    1713
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   326324
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -19991.2793
#
#
#
#
# << end of ENERGY.
# DOPE score               : -19991.279297
# >> Normalized DOPE z score: 0.122
# readlinef__W> File: FM_10.B99990001.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  LEU:OXT  LEU
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713    1713
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   328277
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -20316.8867
#
#
#
#
# << end of ENERGY.
# DOPE score               : -20316.886719
# >> Normalized DOPE z score: 0.021
# readlinef__W> File: FM_10.B99990007.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  LEU:OXT  LEU
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713    1713
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   327156
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -20081.6328
#
#
#
#
# << end of ENERGY.
# DOPE score               : -20081.632812
# >> Normalized DOPE z score: 0.094
# readlinef__W> File: FM_10.B99990009.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  LEU:OXT  LEU
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713    1713
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   328222
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -20341.1348
#
#
#
#
# << end of ENERGY.
# DOPE score               : -20341.134766
# >> Normalized DOPE z score: 0.013
# readlinef__W> File: FM_10.B99990004.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  LEU:OXT  LEU
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713    1713
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   327481
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -20459.0391
#
#
#
#
# << end of ENERGY.
# DOPE score               : -20459.039062
# >> Normalized DOPE z score: -0.024
# readlinef__W> File: FM_10.B99990002.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  LEU:OXT  LEU
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      228
# Number of all, selected real atoms                :     1713    1713
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   325419
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -19982.2363
#
#
#
#
# << end of ENERGY.
# DOPE score               : -19982.236328
# >> Normalized DOPE z score: 0.124
#                  Model  DOPE Score
# 3  FM_10.B99990006.pdb   -0.084752
# 8  FM_10.B99990004.pdb   -0.023645
# 2  FM_10.B99990010.pdb   -0.005116
# 7  FM_10.B99990009.pdb    0.012978
# 5  FM_10.B99990001.pdb    0.020510
# 6  FM_10.B99990007.pdb    0.093585
# 0  FM_10.B99990008.pdb    0.105123
# 4  FM_10.B99990005.pdb    0.121651
# 9  FM_10.B99990002.pdb    0.124460
# 1  FM_10.B99990003.pdb    0.218321

# %% [markdown]
# Verify the modelled side-chains using tools such as:
# - PROCHECK
# - Verify3D
# - WHATCHECK
#
# Some are available at https://saves.mbi.ucla.edu/.
